# %%
# !pip install google-play-scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google_play_scraper import app
import pandas as pd 
import numpy as np

# %%
# Scrape all available views
from google_play_scraper import Sort, reviews_all

us_reviews = reviews_all(
    "com.telkom.tracencare",
    sleep_milliseconds = 0, # defaults to 0
    lang = 'en', # defaults to "en"
    country = 'id', # defaults to "us"
    sort = Sort.MOST_RELEVANT # defaults to Sort.MOST_RELEVANTS
)

# %%
# Scrape desired number of views
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    "com.telkom.tracencare",
    lang = 'en', # defaults to "en"
    country = 'id', # defaults to "us"
    sort = Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANTS
    count = 100, # defaults to 100
    filter_score_with= None # defaults to None (means all score) use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %%
df_busu = pd.DataFrame(np.array(us_reviews),columns=['review'])
df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))
df_busu.head()
# Out:
#                                reviewId             userName  \
# 0  f8817df9-e3d1-428a-95fb-3e6e1bdaca04          Wine Amanda
# 1  0bfdc330-29a5-4d20-8a85-3fc023144bf5            Edward JP
# 2  4523b448-4e2d-4193-9c37-0275bc2ae1c1     AlwaysOn Forever
# 3  16ebdc10-5ede-436b-9766-3433a820a4ac  Canting Carangritti
# 4  9ce3a2c9-714a-4bf4-b943-5c9a7fe99d4a        A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AFdZu...
# 1  https://play-lh.googleusercontent.com/a-/AFdZu...
# 2  https://play-lh.googleusercontent.com/a-/AFdZu...
# 3  https://play-lh.googleusercontent.com/a-/AFdZu...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Its mandatory to use this app to scan the QR c...      4             68
# 1  i was tested positive for covid. yet the app k...      3            339
# ...

# %%
df_busu.shape
# Out:
# (50898, 10)

# %%
len(df_busu.index)
# Out:
# 50898

# %%
my_df = df_busu[['userName', 'score', 'at', 'content']]
my_df.head()
# Out:
#               userName  score                  at  \
# 0          Wine Amanda      4 2022-06-16 03:08:12
# 1            Edward JP      3 2022-02-26 09:42:38
# 2     AlwaysOn Forever      2 2022-01-13 06:53:17
# 3  Canting Carangritti      4 2022-01-12 01:03:58
# 4        A Google user      3 2020-04-21 12:37:10
#
#                                              content
# 0  Its mandatory to use this app to scan the QR c...
# 1  i was tested positive for covid. yet the app k...
# 2  Great idea to make an app like this and make t...
# 3  The apps is helpful for getting into places, m...
# 4  The app stopped working multiple times and I c...

# %%
data_review = my_df[(my_df['at'] >= '2021-09-14') & (my_df['at'] <= '2021-10-14')]
data_review.head()
# Out:
#                userName  score                  at  \
# 16          Rifqi Hatta      4 2021-09-18 19:04:43
# 23  Stanislaus Setyanto      4 2021-09-15 06:03:24
# 30     Bambang Tandjung      1 2021-09-17 06:27:12
# 37             Player 6      1 2021-09-15 17:06:04
# 38              Shine A      1 2021-09-30 04:23:15
#
#                                               content
# 16  Worked as intended, however the notification a...
# 23  At last, the newest apps for tracing covid-19 ...
# 30  Useless, very unreliable. There are lots of bu...
# 37  Insists that my phone is rooted when its not. ...
# 38  Not user-friendly, moreover to elders and plea...

# %%
len(data_review)
# Out:
# 9070

# %%
data_review.to_csv('Scrapped_data.csv', index = False)
